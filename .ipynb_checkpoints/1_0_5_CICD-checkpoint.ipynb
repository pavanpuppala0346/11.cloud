# %% [markdown]
# #### 📘 <b>114.Introduction to CI/CD</b>
#
# **CI/CD** stands for **Continuous Integration** and **Continuous Delivery**.
# It is a practice that automates:
# - Integration of code changes (**CI**)
# - Deployment to higher environments (**CD**)
#
#
# #### 🧱 Why CI/CD for Azure Data Factory?
# After building Data Factory pipelines and a complete data engineering project, the next step is to deploy it beyond the Development environment
# Once Data Factory pipelines are developed, CI/CD helps to:
# - Deployment to **Test**, **QA**, and **Production** environments
# - Ensure automated, reliable, repeatable deployments
# - Reduce manual deployment errors

# %%
from IPython.display import Image
Image('./img/cicd1.png')

# %% [markdown]
# #### 🤝 Collaborative Development with Git
# Also, We want to be able to configure the Development Data Factory with source control tool to enable collaborative development.
# Azure Data Factory supports Git integration for collaborative development.
#
# ##### Benefits of Git Integration:
# - Multiple developers can work together
# - Version control of pipeline code
# - Branching strategies for safe development

# %%
from IPython.display import Image
Image('./img/cicd2.png')

# %% [markdown]
# #### 🧰 Topics Covered in This Module
#
# 1. **Configuring Git with Azure Data Factory**
#    - Connecting ADF to Git repo
#    - Understanding the Development workflow with Git
#
# 2. **Build & Release Pipelines for ADF**
#     - Setting up **Build pipelines (CI)** to validate and publish ADF artifacts
#     - Setting up **Release pipelines (CD)** to deploy ADF code to higher environments
#
# 3. **DevOps & CI/CD Overview**
#     - Understanding key DevOps concepts
#     - How CI/CD streamlines deployments and enhances reliability
#
# 4. **Azure DevOps Services**
#    - Using Azure DevOps for Repos, Build, and Release Pipelines
#
#
#
# #### 🎯 Learning Outcomes
#
# By the end of this module, you will understand:
#
# ✅ What **Continuous Integration (CI)** and **Continuous Delivery (CD)** mean
# ✅ How CI/CD enables automated deployment of **Azure Data Factory** projects
# ✅ How to configure **Git integration** for ADF collaborative development
# ✅ How to create CI/CD pipelines in **Azure DevOps**

# %% [markdown]
# #### 🚀 <b>115.Introduction to CI/CD</b>
#
# **Continuous Integration (CI)** and **Continuous Delivery (CD)** are key **DevOps practices** used to:
# - Deliver software faster to the market
# - Increase confidence and quality in deployments
#
# This section introduces DevOps, CI, and CD, and how they apply to **Azure Data Factory (ADF)**.
#
#
# #### 🤝 Introduction to DevOps
#
# Traditionally, organizations had **two separate teams**:
#
# | Team | Responsibility |
# |------|----------------|
# | Development | Build and test software |
# | IT Operations | Deploy and run applications in production |
#
# #### ❗ Issues with Siloed Teams
# - Poor communication and coordination
# - Conflicting priorities across teams
# - Limited automation and delays
# - Slower time to market and poor product quality
#
# #### ✅ What is DevOps?
# DevOps was introduced around **2007** to:
# - Bring Development and Operations together
# - Work collaboratively throughout the software lifecycle
# - Improve **speed, quality, and automation** of software delivery
#
#
# #### 🧠 Characteristics of DevOps Teams
#
# DevOps teams embrace both **cultural change** and **technology practices**:
#
# #### Key Characteristics:
# - Collaboration, trust, and transparency among team members
# - Use of **Agile methodologies** for iterative development
# - Faster and frequent delivery of small features
# - **CI/CD automation** for code integration and deployment
# - Automated testing and monitoring of applications
# - Continuous improvement through feedback and performance metrics

# %%
from IPython.display import Image
Image('./img/cicd3.png')

# %% [markdown]
# #### 🔄 Modern Software Delivery Lifecycle
#
# Modern development follows a **cyclical workflow**:
#
# 1. **Plan** – gather requirements, define user stories, and plan sprint tasks
# 2. **Develop** – write code
# 3. **Build** – compile or package code
# 4. **Test** – validate functionality through testing
# 5. **Release & Deploy** – deliver the application to environments
# 6. **Monitor & Improve** – track performance and enhance product
#
# This cycle repeats continuously for ongoing improvement.
#
#
# #### 🔧 What is Continuous Integration (CI)?
#
# With many developers contributing code, CI ensures:
# - Code is continuously integrated into a shared repository (e.g., Git)
# - Automated builds are triggered for every code merge
# - Automated tests run with each build
#
# #### 🎯 Goal of CI:
# Catch errors early, improve code quality, and maintain a **stable build**.
#
#
# #### 🚀 Continuous Delivery vs Continuous Deployment
#
# Once code is tested, it must be released and deployed.
#
# | Concept | Explanation |
# |----------|----------------|
# | **Continuous Delivery (CD)** | Code is automatically prepared for deployment. Manual approval is required before going to PROD. |
# | **Continuous Deployment** | No manual intervention. Code is automatically deployed to production once tests pass. |
#
# Both extend CI to ensure reliable and frequent releases.
#
# **Continuous improvement** is achieved through observing the performance of the application and acting upon that.

# %% [markdown]
# #### 🧩 CI/CD in Azure Data Factory (ADF)
#
# You might wonder:
# > “Where is the code in ADF if we design with drag-and-drop?”
#
# #### 📍 Code in ADF
# Every ADF object is stored as **JSON** (pipelines, dataflows, datasets, triggers, etc.).
# This JSON is treated as **code**, enabling version control.
#
# #### 🏗 Build in ADF
# - In programming languages (e.g., Java), a build generates a deployable artifact (e.g., JAR file)
# - For ADF, a build produces an **ARM Template**
#
# #### 📦 What is an ARM Template?
# - ARM = Azure Resource Manager
# - A JSON file that defines the ADF configuration and objects
# - Used to deploy the ADF project to other environments (Test, QA, Prod)

# %% [markdown]
# #### 🧪 Testing ADF Code
#
# - Automated testing is common in development languages (e.g., unit tests)
# - Automated testing for ADF is **not as straightforward**
# - Many teams rely on **manual testing** for ADF
# - A .NET testing framework exists for ADF (optional to explore)
#
#
# #### 🚢 Release & Deployment
#
# After testing:
# - The ARM Template is **released and deployed** to higher environments
# - Deployment creates ADF components (pipelines, triggers, datasets, dataflows, etc.) in target Data Factory
#
# > There are some ADF-specific considerations for deployment (e.g., parameterization, environment variables), which will be covered later.
#
#
# #### ✅ Summary
#
# By now, you should understand:
#
# - What DevOps is and why it was created
# - How DevOps improves collaboration and delivery speed
# - The difference between CI, CD, and Continuous Deployment
# - How CI/CD applies to Azure Data Factory
# - The role of **ARM Templates** in ADF deployment
#
# This foundation sets the stage for learning **CI/CD implementation for ADF**.

# %% [markdown]
# #### <b>116. CI/CD for Azure Data Factory – Option 1 (ADF Publish Method)</b>
#
# In this section, we take a deeper look at how to implement Continuous Integration (CI) and Continuous Delivery (CD) for Azure Data Factory (ADF) artifacts.
#
# The CI/CD practice for ADF has evolved over time. Up until recently, Microsoft recommended a **manual build** using the **Publish** button in ADF Studio, followed by an **automated deployment** using release pipelines. Most industry projects still follow this approach.
#
# Microsoft has now introduced a package to perform **automated build**, enabling a fully automated CI/CD solution for ADF. This newer approach will be explained later.
#
# ---
#
# #### ✅ CI/CD Approaches for ADF
#
# | Option | Name | Build Method | Deployment Method | Status |
# |--------|-------|----------------|---------------------|----------|
# | **Option 1** | ADF Publish Approach | Manual build via Publish button | Automated Release Pipeline | Widely used |
# | Option 2 | Fully Automated CI/CD | Automated build via Microsoft package | Automated Release Pipeline | Recommended for new projects |
# | Option 3 | ADF Tools (Marketplace) | Third‑party tool | Automated | Optional |
#
# > **This notebook covers Option 1 (ADF Publish method).**
#
# ---

# %%
from IPython.display import Image
Image('./img/cicd4.png')

# %%
from IPython.display import Image
Image('./img/cicd5.png')

# %% [markdown]
# #### 🔹 Recap of Development Flow (So Far)
#
# Until now, we followed this approach while building the COVID‑19 ADF project:
#
# 1. Open ADF Studio in **Live Mode**
# 2. Create pipelines, dataflows, triggers, etc.
# 3. Debug pipelines
# 4. Click **Publish**
# 5. ADF validates artifacts and publishes to ADF repository

# %%
from IPython.display import Image
Image('./img/cicd6.png')

# %% [markdown]
# <b> Drawback of Live Mode : The key point to remember here is that we directly connected ADF Studio to the ADF repository and made all the changes there. This way of connecting to the ADF repository is referred to as live mode.</b>
#
# Live mode directly connects developers to the ADF service and repository. This causes limitations:
#
# - No collaboration for multiple developers
# - No version control (cannot rollback)
# - No code review / pull request process
# - Changes can overwrite each other
#
# This is not suitable for real‑world enterprise projects.

# %%
from IPython.display import Image
Image('./img/cicd7.png')

# %% [markdown]
# #### 📌 Git Integration for ADF (Git Mode)
#
# To enable collaboration, versioning, and review process, we integrate ADF with Git.
#
# #### Supported Git Repositories
#
# - Azure DevOps Repos ✅ *(we will use this)*
# - GitHub
#
# #### How Git Mode Helps
#
# | Capability | Benefit |
# |-------------|------------|
# | Feature branches | Developers work independently |
# | Commit changes | Save work incrementally |
# | Pull Requests | Enable review & approvals |
# | Version Control | Rollback changes |
# | Merge to master/main | Controlled integration |
#
# #### Flow with Git Mode
#
# 1. Developer creates **feature branch**
# 2. Makes changes and commits
# 3. Submits PR for review
# 4. Merge into **main/master** branch
# 5. Click **Publish** in ADF
#
# ---
#
# #### 🧱 What Happens When We Click Publish?
#
# The **Publish** button performs a **manual build** step.
#
# On publish, two things happen:
#
# | Output | Explanation |
# |----------|----------------|
# | Changes published to ADF Dev environment | Updates Data Factory service |
# | **`adf_publish` branch generated** | Contains ARM templates for deployment |
#
# #### What is in the `adf_publish` Branch?
#
# The branch contains:
#
# - ARM Templates (JSON files)
# - Parameters file for environment variables
#
# These files are used for deploying ADF to higher environments (Test, Prod) via Release Pipeline.
#
# > 📍 **Publish = Build step of Continuous Integration**
#
# ---
#
# #### 🚀 Deployment to Higher Environments
#
# After Publish creates ARM templates, an **Azure DevOps Release Pipeline** deploys them to:
#
# - Test
# - Production
#
# So, in **Option 1**:
#
# | Stage | Automation |
# |----------|----------------|
# | Build (Publish) | ❌ Manual |
# | Release / Deploy | ✅ Automated |
#
# This is why Option 1 is called **Manual Build + Automated Deploy**.
#
# ---
#
# #### 🧠 Summary of Option 1 – ADF Publish Method
#
# - Developers work in Git mode with feature branches
# - Manual **Publish** generates ARM templates (`adf_publish` branch)
# - Azure DevOps Release Pipeline deploys ARM templates to Test/Prod
# - CI is partially automated (manual build), CD is automated
#
# This option is still used in many companies and interviews may refer to it as:
#
# - **ADF Publish Approach**
# - **Manual Build – Automated Deploy**
# - **Option 1 CI/CD for ADF**
#
# ---
#
# You now understand the key concepts behind Option 1. In the next lesson, we will build the first CI/CD pipeline.

# %% [markdown]
# #### <b>117. Introduction to Azure DevOps</b>
#
# #### 🚀 What is Azure DevOps?
#
# **Azure DevOps** is a **Software as a Service (SaaS)** platform offered by Microsoft.
# It provides a suite of tools to implement DevOps practices end‑to‑end on the Azure cloud.
#
# Azure DevOps enables teams to plan, develop, build, test, release, and monitor software efficiently.
#
# ---
#
# #### 🧩 Key Services in Azure DevOps
#
# Azure DevOps offers **five core services**, each supporting different DevOps functions:
#
# #### 1. **Azure Boards**
# Used for project and work management.
#
# **Key Capabilities:**
# - Create and manage user stories, tasks, bugs
# - Supports **Agile**, **Scrum**, and **Kanban**
# - Track progress with dashboards & charts
# - Enables team collaboration and reporting
#
# ---
#
# #### 2. **Azure Repos**
# Provides source code version control capabilities.
#
# **Supports:**
#
# | Type | Description |
# |-------|----------------|
# | **Git** | Distributed version control – most widely used |
# | **TFVC** | Team Foundation Version Control – centralized system |
#
# Teams use Azure Repos to store code, manage branches, perform code reviews, and maintain version history.
#
# ---
#
# #### 3. **Azure Pipelines**
# Provides build and release automation for CI/CD.
#
# **Capabilities:**
# - Supports Continuous Integration (CI)
# - Supports Continuous Delivery/Deployment (CD)
# - Works with multiple languages and platforms (.NET, Java, Python, Node, etc.)
# - Can deploy to Azure, AWS, GCP, on‑prem servers, and containers
#
# ---
#
# #### 4. **Azure Test Plans**
# A browser‑based solution for test management.
#
# **Supports:**
# - Manual testing and test planning
# - User acceptance testing (UAT)
# - Exploratory testing
# - Capturing stakeholder feedback and responses
#
# ---
#
# #### 5. **Azure Artifacts**
# A package management & library service.
#
# **Use Cases:**
# - Store and share packages or build artifacts
# - Can be used in CI/CD pipelines
# - Supports NuGet, npm, Maven, Python packages, etc.
#
# Example: Store reusable code libraries or deployment modules to share across projects.

# %%
from IPython.display import Image
Image('./img/cicd8.png')

# %% [markdown]
# #### 🏗️ How Azure DevOps is Organized
#
# Azure DevOps has a hierarchy to organize work, code, and teams.
#
# #### 🔹 **Organization**
# - Top‑level container for projects
# - A company may have **one** or **multiple** organizations based on structure and security
#   e.g., one per business unit or department
#
# #### 🔹 **Projects**
# Each **organization** can contain multiple projects.
#
# Each project includes:
# - Boards
# - Repos
# - Pipelines
# - Test Plans
# - Artifacts
#
# #### 🔹 **Teams**
# - Multiple teams can exist within a project
# - A team can work across more than one project
# - Defines permissions, boards view, and workflows
#
# > For this course, we will keep project structure simple and focus on only the needed components.
#
# ---
#
# #### ✅ Summary
#
# Azure DevOps provides a full ecosystem for DevOps implementation, including:
#
# | Service | Purpose |
# |----------|-----------|
# | Azure Boards | Work & project management |
# | Azure Repos | Source code version control |
# | Azure Pipelines | CI/CD automation |
# | Azure Test Plans | Testing & feedback management |
# | Azure Artifacts | Package and artifact repository |
#
# You should now have a clear understanding of Azure DevOps and how it is structured.

# %% [markdown]
# ### <b>118. Creating Azure DevOps Organization & Project (Azure DevOps starts from here..!)</b>
#
# In the previous lesson, we understood what Azure DevOps is.
# In this lesson, we will walk through:
#
# ✅ Signing into Azure DevOps
# ✅ Creating an Azure DevOps Organization
# ✅ Linking to the correct Azure Active Directory (AAD)
# ✅ Creating a Project inside the Organization
# ✅ Quick tour of Azure DevOps services
# ✅ Enabling free parallelism for CI/CD pipelines
#
# ---
# #### 🔐 **Step 1: Sign in to Azure DevOps**
#
# 1. Open your browser and go to:
#    👉 https://dev.azure.com
# 2. Click **Sign in to Azure DevOps**
# 3. Select the same Microsoft account used for Azure Portal
# 4. Enter password → **Sign In**
# 5. Click **Continue**
#
# > ⚠️ Do **NOT** continue on the next screen yet — We must choose the correct directory first.
#
# #### 🧭 **Step 2: Select the Correct Azure Active Directory (AAD)**
#
# Azure DevOps needs to be linked to the same directory where your Azure resources (like ADF) are created.
#
# 1. Click **Switch Directory**
# 2. Identify the correct directory:
#    - Go to https://portal.azure.com
#    - On the top-right corner, click your profile → Check AAD name
# 3. Select the same directory in Azure DevOps
# 4. Click **Continue**
#
# > Most users will see **Default Directory**.
# > For corporate environments, ensure you pick the correct organization-specific directory.
#
# #### 🏢 **Step 3: Create Azure DevOps Organization**
#
# 1. Select your country/region
# 2. Enter a unique **Organization Name**
#    - Example: `GID-Data-Engineering`
#    - If name not available → append numbers/initials
# 3. Enter CAPTCHA characters
# 4. Click **Continue**
#
# Once created, you will land inside your Azure DevOps organization.
#
# To view org details:
# `Organization Settings → Overview`
#
# #### 💳 **Step 4: Understand Free Azure DevOps Licensing**
#
# Azure DevOps offers a free tier suitable for learning and personal projects.
#
# | Feature | Free Allowance |
# |--------|----------------|
# | Users | 5 users free |
# | CI/CD (Microsoft hosted agents) | 1,800 mins/month |
# | Self-hosted CI/CD | Unlimited |
# | Artifacts Storage | 2 GB |
#
# > This is more than sufficient for ADF + CICD learning.
#
# #### ⚙️ **Enable Free Parallelism (Optional but Recommended)**
#
# Microsoft requires a request to enable **free parallel jobs**.
#
# 🔗 Form link:
# https://aka.ms/azpipelines-parallelism-request
#
# Fill the form:
#
# | Field | What to Enter |
# |-------|----------------|
# | Name | Your name |
# | Email | Your login email |
# | DevOps Organization URL | Copy from Azure DevOps → Organization Overview (https://dev.azure.com/GID-Data-Engineering) |
# | Project Type | Select **Private** |
#
# Approval usually takes **< 48 hours**.
#
# #### 📁 **Step 5: Create a New Azure DevOps Project**
#
# Two ways to create a project:
#
# #### ✅ Option 1: From Organization Home
# - Click **Azure DevOps** logo (top-left)
# - Click **New Project**
#
# #### ✅ Option 2: From Projects Page
# - Click **Projects**
# - Click **New Project**
#
# #### 📍 Provide the following:
#
# | Field | Value |
# |-------|--------|
# | Project Name | Example: `ADF-CICD` |
# | Visibility | **Private** |
# | Version Control | **Git** (recommended) |
# | Work Item Process | Basic / Agile / Scrum / CMMI |
#
# > For learning: Choose **Basic**
#
# Click **Create Project** ✅

# %%
from IPython.display import Image
Image('./img/cicd19.png')

# %%
from IPython.display import Image
Image('./img/cicd20.png')

# %% [markdown]
# #### 🚀 **Azure DevOps Project Layout (Quick Tour)**
#
# Inside your project, you will see 5 core services:
#
# | Service | Purpose |
# |---------|----------|
# | **Boards** | Requirements, backlog, sprints, Kanban |
# | **Repos** | Git code repositories |
# | **Pipelines** | Build + Release CICD |
# | **Test Plans** | Manual testing & QA |
# | **Artifacts** | Package management (like NPM, NuGet) |
#
# For ADF CICD, we will use:
#
# ✔️ **Repos** – Store ADF code
# ✔️ **Pipelines** – Build & Release CICD
#
# We will **not** use Boards, Test Plans, Artifacts for this course.

# %% [markdown]
# #### 📓 <b>119. Creating Azure Data Factory Resources for CI/CD</b>
#
# In this note, we will create the required **Azure Data Factory (ADF)** resources for implementing CI/CD.
# We will **not reuse** the Data Factory from the COVID project — instead, we will create new ones with naming standards aligned to DevOps practices.
#
# ---
#
# #### 🎯 Why Create New Data Factories?
#
# We want a **clean setup** to implement CI/CD from scratch, so that we can:
#
# ✅ Apply proper naming conventions
# ✅ Configure Git integration from the beginning
# ✅ Observe CI/CD effects across environments
#
# ---
#
# #### 🏗️ Required Data Factories for CI/CD
#
# A standard Azure DevOps project typically requires multiple ADF instances across environments:
#
# | Environment | Purpose | Git Enabled? | Notes |
# |-------------|-----------|----------------|--------|
# | **Dev** | Development & CI | ✅ Yes | Developers commit & collaborate |
# | **Test** | Testing (Integration/UAT) | ❌ No | Code deployed via CD pipeline |
# | **Prod** | Production execution | ❌ No | Final deployment stage |
#
# > In enterprise environments, there may be additional environments (e.g., QA, UAT, Pre‑Prod).
# For simplicity, we will use **Dev → Test → Prod**.

# %%
from IPython.display import Image
Image('./img/cicd9.png')

# %% [markdown]
# #### 🔖 Naming Standards
#
# To maintain consistency and enable automation in pipelines, we follow a naming pattern:
#
# ```
# <environment>-ci-cd-demo-<resource>
# ```
#
# #### 📍 Resource Naming Table
#
# | Resource | Dev Name | Test Name | Prod Name |
# |-----------|-------------|-------------|--------------|
# | Resource Group | `dev-ci-cd-demo-rg` | `test-ci-cd-demo-rg` | `prod-ci-cd-demo-rg` |
# | Data Factory | `dev-ci-cd-demo-adf` | `test-ci-cd-demo-adf` | `prod-ci-cd-demo-adf` |
#
# 💡 Only the **Dev ADF** will be connected to Git — Test & Prod ADFs receive code via deployment pipelines.

# %%
from IPython.display import Image
Image('./img/cicd10.png')

# %% [markdown]
# #### ⚙️ Steps to Create the Data Factories
#
# 1. Sign into **Azure Portal** → https://portal.azure.com
# 2. Navigate to **Create a Resource**
# 3. Search for **Data Factory**
# 4. Create the Dev Data Factory first:
#
# | Field | Value |
# |--------|---------|
# | Subscription | Your Subscription |
# | Resource Group | `dev-ci-cd-demo-rg` |
# | Data Factory Name | `dev-ci-cd-demo-adf` |
# | Region | Closest to you (e.g., UK South) |
# | Version | V2 |
# | Git Configuration | Configure later |
#
# 5. Repeat the same steps to create Test & Prod Data Factories – without Git config.
#
# ---
#
# #### ✅ Final Check
#
# After creation, you should see **three** Data Factories in Azure Portal:
#
# | Data Factory | Resource Group |
# |----------------|--------------------|
# | dev-ci-cd-demo-adf | dev-ci-cd-demo-rg |
# | test-ci-cd-demo-adf | test-ci-cd-demo-rg |
# | prod-ci-cd-demo-adf | prod-ci-cd-demo-rg |

# %% [markdown]
# #### <b> 120. Configuring Git Integration with Azure Data Factory</b>
# #### 📘 Overview
# This notebook provides detailed notes on how to configure a Git repository for Azure Data Factory (ADF) development. It also explains key ADF Git concepts such as collaboration branches, feature branches, and the `adf_publish` branch.
#
# #### 🔑 Key Git Concepts for ADF
# Before configuring Git integration, it’s important to understand a few ADF‑specific Git terminologies:
#
# #### ✔ Recommended Branching Strategy
# Microsoft recommends the following branching approach for ADF:
#
# | Branch | Purpose |
# |--------|-----------|
# | **Main/Master (Collaboration Branch)** | The only branch from which code can be **Published** to ADF. No direct development allowed. |
# | **Feature Branches** | Created from Main for development work. Merged via Pull Request (PR). |
# | **adf_publish** | Auto‑generated branch after Publish. Contains ARM templates for deployment. |
#
# 🔹 **Developers must never develop directly on main.**
#
# Publishing from main triggers creation/update of the `adf_publish` branch containing ARM templates required for deployments.

# %%
from IPython.display import Image
Image('./img/cicd11.png')

# %% [markdown]
# #### 🧰 Step 1: Create a Git Repository in Azure DevOps
# You can either:
# - Create a repo in Azure DevOps first **(recommended)**, then link ADF to it, or
# - Let ADF create the repo for you
#
# Here is the recommended approach:
#
# 1. Go to Azure DevOps > Select your Project
# 2. Navigate to **Repos**
# 3. Click **New Repository**
# 4. Name the repository(`gid-de-dev-adf`) same as the ADF(`gid-de-dev-adf`) instance for easy mapping
#
# > ✅ Recommended Naming: Use the same name as the ADF instance (e.g., `dev-ci-cd-demo-adf`)
#
# #### 🔧 Step 2: Configure Branch Policies
# To enforce proper CI/CD workflows:
#
# 1. Go to **Repos → Branches**
# 2. Select the `main` branch
# 3. Click **... → Branch Policies**
# 4. Enable:
#    - ✅ Minimum number of reviewers (e.g., 2 — but use 1 for learning/demo)
#    - ✅ Require pull request to merge
#
# 📍 In real projects: *Do NOT allow requestors to approve their own PRs*
#
# > This ensures quality code review and prevents direct commits to main.
#
# #### 🔗 Step 3: Configure Git in Azure Data Factory
# 1. Open **ADF Studio** for the Dev Data Factory
# 2. Navigate to one of the following:
#    - Home screen → **Set up Code Repository**
#    - Author tab → Git dropdown → **Set up Code Repository**
#    - Manage tab → **Git Configuration → Configure**
#
# #### Fill in Configuration:
# | Field | Value |
# |-------|--------|
# | Repository Type | Azure DevOps Git |
# | Azure AD Tenant | Default Directory (or the one used for ADF resources) |
# | DevOps Organization | Select your organization `GID-Data-Engineering` |
# | Project | Select the DevOps project created `ADF` |
# | Repository | Select the repo created (e.g., `gid-de-dev-adf`) |
# | Collaboration Branch | `main` or `master` |
# | Publish Branch | `adf_publish` (auto‑selected) |
#
# 📍 If moving existing pipelines to Git, enable *Import Existing Resources*. For a clean start, leave unchecked.

# %% [markdown]
# #### 🧪 After Configuration
# Once the setup is complete:
#
# - ADF switches to **Git mode** instead of Live mode
# - You will see branch name at the top bar of ADF Studio
# - You must now **create a feature branch** before making changes
#
# ⚠️ If you try to work on main branch, ADF will show an error because branch policies prevent direct edits.
#
# #### 🏁 Summary
# You have now:
# ✅ Created a Git Repo in Azure DevOps
# ✅ Applied branch policies to protect the main branch
# ✅ Integrated ADF with Azure DevOps Git
#
# This sets the foundation for CI (Continuous Integration) before enabling automated deployments (CD).

# %%
from IPython.display import Image
Image('./img/cicd21.png')

# %%
from IPython.display import Image
Image('./img/cicd22.png')

# %%
from IPython.display import Image
Image('./img/cicd23.png')

# %% [markdown]
# <b>121. Azure Data Factory Code Development using Git</b>

# %%
from IPython.display import Image
Image('./img/cicd12.png')

# %%
from IPython.display import Image
Image('./img/cicd24.png')

# %%
from IPython.display import Image
Image('./img/cicd25.png')

# %% [markdown]
# <b>121. Option 1 - Manual Build</b>

# %%
from IPython.display import Image
Image('./img/cicd13.png')

# %%
from IPython.display import Image
Image('./img/cicd26.png')

# %% [markdown]
# <b>123. Option 1 - Release Pipeline Design</b>

# %%
from IPython.display import Image
Image('./img/cicd14.png')

# %%
from IPython.display import Image
Image('./img/cicd15.png')

# %% [markdown]
# #### 🔁 Overview of Continuous Delivery
# Continuous Delivery begins once the **Continuous Integration (CI)** process is completed.
#
# The output of CI is the **ARM Template** generated and stored in the `adf_publish` branch. This ARM template must be deployed to different environments such as **Test** and **Production** using a Release Pipeline.

# %%
from IPython.display import Image
Image('./img/cicd16.png')

# %%
from IPython.display import Image
Image('./img/cicd17.png')

# %% [markdown]
# #### 🚀 CD Deployment Flow
# Below is the typical flow for CD in ADF:
#
# 1. Build pipeline generates ARM template into `adf_publish` branch
# 2. Release pipeline picks the ARM template
# 3. Deploy to **Test ADF**
# 4. On success, a **manual approval** is triggered
# 5. Once approved, deploy to **Production ADF**
#
# > ⚠️ While full automation exists (e.g., Netflix style auto-deploy to prod), most enterprises mandate a **manual approval** before prod deployment.

# %%
from IPython.display import Image
Image('./img/cicd18.png')

# %% [markdown]
# #### 📦 Release Pipeline Structure
# A release pipeline in Azure DevOps for ADF generally contains **two stages**:
#
# | Stage | Description |
# |--------|----------------|
# | **Test** | Deploy ARM template to Test ADF |
# | **Production** | Deploy ARM template to Prod ADF after approval |
#
# Each stage contains **three jobs**:
#
# | Job | Purpose |
# |--------|----------------|
# | **Pre‑Deployment (PowerShell)** | Stop triggers and handle cleanup before deployment |
# | **ARM Template Deployment** | Deploy changes (add or update DF assets) |
# | **Post‑Deployment (PowerShell)** | Start triggers and remove deleted objects |
#
# #### ❗ Why Pre & Post Deployment Scripts Are Needed
# ADF ARM Template deployment has two limitations:
#
# | Limitation | Issue It Causes |
# |------------|-----------------|
# | Does not delete objects | If a pipeline/activity is removed, it **remains in target ADF** |
# | Cannot update active triggers | Deployment **fails if triggers are running** |
#
# ✅ To resolve this, Microsoft provides a **PowerShell deployment script** which:
# - Stops triggers before deployment
# - Deploys ARM template
# - Cleans up deleted objects
# - Restarts triggers

# %%
from IPython.display import Image
Image('./img/cicd27.png')

# %% [markdown]
# #### 🏗️ Final Release Pipeline Design
# The Release pipeline will:
#
# - Take ARM template from `adf_publish` branch as **source artifact**
# - Have **two stages**: Test → Production
# - Test stage runs all 3 jobs
# - Production stage runs same 3 jobs but **only after manual approval**
#
# ```text
# Release Pipeline
# │
# ├── Stage 1: Test
# │   ├── Pre-Deployment PowerShell Job
# │   ├── ARM Template Deployment Job
# │   └── Post-Deployment PowerShell Job
# │
# └── Stage 2: Production (requires approval)
#     ├── Pre-Deployment PowerShell Job
#     ├── ARM Template Deployment Job
#     └── Post-Deployment PowerShell Job
# ```

# %% [markdown]
# <b> 124. Option 1 - Creating ARM Deployment Task </b>

# %%
from IPython.display import Image
Image('./img/cicd28.png')

# %%
from IPython.display import Image
Image('./img/cicd29.png')

# %%
from IPython.display import Image
Image('./img/cicd30.png')

# %%
from IPython.display import Image
Image('./img/cicd31.png')

# %%
from IPython.display import Image
Image('./img/cicd32.png')

# %% [markdown]
# <b>125. Option 1 - Testing ARM Deployment Task</b>
